# %% [markdown]
# ## Q/A solution
#
# in this notebook we check how a function provides an answer to a python question.
#
# **NOTE**: in this case we use the same question I generated to make an python solution for it. In class
# you will need to answer **different** questions from the ones you generated

# %%
import importlib.util
import sys

# load the question use case generator (given by repo of the student that generated the question) 
spec = importlib.util.spec_from_file_location('q', 'myquestions/question-001-usecase-generator.py')
q = importlib.util.module_from_spec(spec)
sys.modules['q'] = q
spec.loader.exec_module(q)

# load the answer you develop
spec = importlib.util.spec_from_file_location('q', 'myanswers/answer-129.py')
a = importlib.util.module_from_spec(spec)
sys.modules['a'] = a

spec.loader.exec_module(a)

# %% [markdown]
# ## generate a use case

# %%
args, output = q.generar_caso_de_uso_preparar_datos()
print (args)
# Out:
# {'df':    feature_0  feature_1  feature_2  target_variable
# 0  -0.123261   0.363054   0.857962                1
# 1  -0.184016        NaN  -0.102348                0
# 2   0.766932   1.072359   0.215208                0
# 3   1.205191   0.562398   2.110872                0
# 4  -0.468267   0.188941  -0.661135                1
# 5  -1.390687   0.105368  -0.553030                1, 'target_col': 'target_variable'}

# %% [markdown]
# ## run my solution function

# %%
a.preparar_datos(**args)
# Out:
# (array([[-1.08185715e-01, -3.03082875e-01,  5.75729028e-01],
#         [-1.80486817e-01,  1.76412263e-16, -4.35559482e-01],
#         [ 9.51176310e-01,  1.95106293e+00, -1.01145240e-01],
#         [ 1.47272050e+00,  3.30425251e-01,  1.89515083e+00],
#         [-5.18755622e-01, -8.56406555e-01, -1.02400968e+00],
#         [-1.61646866e+00, -1.12199875e+00, -9.10165462e-01]]),
#  array([1, 0, 0, 0, 1, 1]))

# %%
## check if my solution matches the ex

# %%
output
# Out:
# (array([[-1.08185715e-01, -3.03082875e-01,  5.75729028e-01],
#         [-1.80486817e-01,  1.76412263e-16, -4.35559482e-01],
#         [ 9.51176310e-01,  1.95106293e+00, -1.01145240e-01],
#         [ 1.47272050e+00,  3.30425251e-01,  1.89515083e+00],
#         [-5.18755622e-01, -8.56406555e-01, -1.02400968e+00],
#         [-1.61646866e+00, -1.12199875e+00, -9.10165462e-01]]),
#  array([1, 0, 0, 0, 1, 1]))
